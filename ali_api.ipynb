# %%
#Import module Service, pandas and matplot
import Service as sv
import pandas as pd
import matplotlib.pyplot as plt

aliapi = sv.AliApi('US')

# %%
todoSearch = aliapi.getProductsbySearch('carro',20,30)
if len(todoSearch) > 0:
    df = pd.DataFrame(todoSearch['docs'])
df
# Out:
#     app_sale_price app_sale_price_currency        product_id  \
# 0            26.00                     USD  1005003296335314
# 1            29.80                     USD  1005003296433742
# 2            29.80                     USD  1005003296267395
# 3            29.69                     USD  1005003295607870
# 4            26.58                     USD  1005003295642280
# 5            21.35                     USD  1005003290937645
# 6            23.69                     USD  1005003290614105
# 7            21.19                     USD  1005003294889970
# 8            28.18                     USD  1005003294943542
# 9            29.16                     USD  1005003294895974
# 10           23.66                     USD  1005003294907863
# 11           24.98                     USD  1005003294488365
# 12           27.99                     USD  1005003294078528
# 13           25.35                     USD  1005003294119678
# ...

# %%
todoFeedbacks = aliapi.getFeedbacksbyProduct('4000552751596')
if len(todoFeedbacks) > 0:
    dfeed = pd.DataFrame(todoFeedbacks['docs'])
dfeed
# Out:
#                  name displayName country  rating  \
# 0               E***A                  CO       5
# 1               S***z                  MX       5
# 2               A***i                  BH       5
# 3               A***r                  HU       5
# 4               A***I                  DZ       1
# 5  AliExpress Shopper                  ES       1
# 6               O***r                  RU       1
# 7               A***v                  RU       1
# 8               E***k                  RU       5
# 9               G***a                  MX       5
#
#                                                 info  \
# 0  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# 1  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# 2  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# 3  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# 4  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# 5  {'Ships From:': 'China', 'Logistics:': 'Cainia...
# ...

# %%
todoBestSales = aliapi.getProductsbyBestSales('carro', 4, 500)
if len(todoBestSales) > 0:
    dfBs = pd.DataFrame(todoBestSales['docs'])
dfBs
# Out:
#                         _id first_level_category_id  \
# 0  5f7215468608920011b26b59                      21
# 1  60fe5da74de1c30012e9b96d                      26
# 2  60fe5ef84de1c30012eb54b7               200000345
# 3  5f7220468608920011b63185               200000345
# 4  5f812f9b2a8a6e00118efcfd                      34
# 5  5f7642928608920011c90edf               200000345
#
#           first_level_category_name  \
# 0          Office & School Supplies
# 1                    Toys & Hobbies
# 2                  Women's Clothing
# 3                  Women's Clothing
# 4  Automobiles, Parts & Accessories
# 5                  Women's Clothing
#
#                                   product_detail_url        product_id  \
# 0  https://www.aliexpress.com/item/4000675256172....     4000675256172
# 1  https://www.aliexpress.com/item/4001212365163....     4001212365163
# 2  https://www.aliexpress.com/item/10050012816099...  1005001281609962
# ...
